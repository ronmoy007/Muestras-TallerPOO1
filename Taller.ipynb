# %%
################ Taller de Programación Orientada a objetos -for the real world- ################

# ¿De qué se trata esto?
# -Es un taller express para brindar nociones básicas de programación orientada
# a objetos para el mundo real.

# ¿Debo saber programar?
# -Debes saber los siguientes 3 conceptos:
#  -Variable
#  -Función
#  -Parámetro
# -Con que conozcas bien esos 3 términos, ya tienes las bases mínimas para seguir el taller.

# ¿Qué cosas veremos en el taller?
# -Lo básico:
#  -Clases
#  -Atributo
#  -Método
#  -Objetos

# -Lo intermedio:
#  -Herencia

# -Lo avanzado:
#  -No habrá cosas avanzadas (ya serían cosas muy específicas de ingeniería de software 
#   y ahorita ni al caso).

# -¿Habrá ejemplos?
#  -¡Sí, varios!

# -¿Programaremos un turista?
#  -Lo siento amigos, no habrá turista

# %%
# ¿Qué es la programación orientada a objetos (POO)?
# -Es un paradigma de programación en el cual se trata abstraer la realidad y plasmarla en 
#  el código de tal manera que las interacciones del código se asemejen mucho al mundo real.

# ¿Cómo se logra esto?
# -Se logra a partir de elegir un ente del mundo real, y crear una PLANTILLA de dicho ente
#  en el cual se incluyan: las cosas QUE LO DESCRIBEN y las cosas QUE SABE HACER.

# ¿Por qué debo aprender programación orientada a objetos?

# -1. Allá afuera ya hay mucho código, y seguro te tocará hacerle ajustes, correcciones o
#  alguna otra cosa, y es muy probable que ese código esté escrito bajo este paradigma.
#  Así que no se trata de que te hagas experto, sino de que tengas las bases para entender
#  qué es lo que hace el código que estés revisando.

# -2. Scikit-learn, tensorflow y cuanta librería se te ocurra, está escrita en clases. De 
#  hecho seguro ya las has usado. Teniendo las nociones de qué significan los conceptos de 
#  este paradigma, seguro te ayudarán a sacarle más provecho a esas librerías.

# -3. Este tipo de desarrollos pueden ser muy escalables y de fácil mantenimiento si lo planteas
#  de una manera adecuada. Por lo que si tienes que hacer un desarrollo desde cero, puede ser
#  una muy buena opción.

# ¿O sea que la programación orientada a objetos es lo mejor de lo mejor?
# -Resulta ser muy buena alternativa (sobretodo cuando se trata de desarrollos medianos y grandes).
#  En mi caso yo la evito en desarrollos pequeños (y que sé que no van a crecer).
#  Peeeeeero yo te recomendaría que justo empieces a usar POO en los desarrollos pequeños para
#  que practiques.

# ¿Cómo saber si voy bien en la POO?
# -Lo sabrás en el punto en el que veas tus códigos anteriores y digas: 
#  "¡Dios mío qué horror! ¿en qué estaba pensando? Eso lo pude haber hecho de otra manera y 
#  hubiera quedado más entendible y funcional"

# %%
##############################  Everything is possible...  ###############################
##############################                             ###############################
##############################                   -Nasser-  ###############################

# %%
# Ejemplo 1
class Persona():
    str_Nombre = ''

# %%
################ Terminología de Programación Orientada a objetos ################

# A las variables que viven dentro de una clase se les dice ATRIBUTOS

# %%
obj_Persona = Persona()

# %%
################ Terminología de Programación Orientada a objetos ################

# A la variable obj_Persona se le dice OBJETO porque se creó a partir de una CLASE
# Cuando se crea un OBJETO a partir de una clase, se dice que dicha clase fue INSTANCIADA

# Se usan indistintamente las siguientes frases: <Creamos el objeto> o <Instanciamos la clase>

##################################################################################

# %%
obj_Persona

# %%
obj_Persona.str_Nombre

# %%
############################## El operador punto . ##############################
# En la programación orientada a objetos, usamos el operador punto (.) para 
# acceder a los elementos que "viven" dentro de la clase

# %%
obj_Persona.str_Nombre = 'Diego'

# %%
obj_Persona.str_Nombre

# %%
### QUIZ: ¿Qué pasa si le pedimos algo que no existe dentro de la clase?
obj_Persona.str_Apellido

# %%
### QUIZ: ¿Esto va a funcionar?
obj_Persona.str_Apellido = 'Villa'

# %%
obj_Persona.str_Apellido

# %%
### QUIZ: Si ya se creo 'al vuelo' el atributo str_Apellido, ¿Aquí también va a funcionar?
obj_Persona_2 = Persona()
obj_Persona_2.str_Apellido

# %%
# Ejemplo 2
class Persona():
    
    str_Nombre = ''
    str_Apellido = ''
    
    def Saludar():
        print('¡Hola!')

# %%
################ Terminología de Programación Orientada a objetos ################

# A las funciones que viven dentro de una clase, se les dice MÉTODOS

# %%
obj_Persona = Persona()

# %%
### QUIZ: Pues en teoría funciona... ¿cierto?
obj_Persona.Saludar()

# %%
Persona.Saludar(obj_Persona)

# %%
### Ejemplo 3
class Persona():
    
    str_Nombre = ''
    str_Apellido = ''
    
    def Saludar(parametro_requerido):
        print('¡Hola!')

# %%
obj_Persona = Persona()

# %%
obj_Persona.Saludar()

# %%
Persona.Saludar(obj_Persona)

# %%
# Ejemplo 4
class Persona():
    
    str_Nombre = ''
    str_Apellido = ''
    
    def Saludar(parametro_requerido):
        print('¡Hola!')
        
    def Presentarse(parametro_requerido):
        print('Mi nombre es: ', str_Nombre)

# %%
obj_Persona = Persona()
obj_Persona.str_Nombre = 'Diego'
obj_Persona.str_Apellido = 'Villa'

# %%
obj_Persona.str_Nombre

# %%
obj_Persona.Saludar()

# %%
### QUIZ: ¿Jalará?
obj_Persona.Presentarse()

# %%
# Ejemplo 5
class Persona():
    
    str_Nombre = ''
    str_Apellido = ''
    
    def Saludar(parametro_requerido):
        print('¡Hola!')

    def Presentarse(parametro_requerido):
        print('Mi nombre es: ', self.str_Nombre)

# %%
obj_Persona = Persona()
obj_Persona.str_Nombre = 'Diego'
obj_Persona.str_Apellido = 'Villa'

# %%
### QUIZ: Ya con el self santo remedio... ¿o no?
obj_Persona.Presentarse()

# %%
# Ejemplo 6
class Persona():
    
    str_Nombre = ''
    str_Apellido = ''
    
    def Saludar(parametro_requerido):
        print('¡Hola!')
        
    def Presentarse(parametro_requerido):
        print('Mi nombre es: ', parametro_requerido.str_Nombre)

# %%
obj_Persona = Persona()
obj_Persona.str_Nombre = 'Diego'
obj_Persona.str_Apellido = 'Villa'

# %%
### No lo sé Rick, parece falso...
obj_Persona.Presentarse()

# %%
Persona.Presentarse(obj_Persona)

# %%
################ Programación Orientada a objetos en Python ################

# La palabra self, NO ES UNA PALABRA RESERVADA y no es una manera directa de llegar al atributo que queremos

# La palabra self, es el nombre POR CONVENCIÓN que se decidió usar para cachar el parámetro que siempre añade
# python al mandar a llamar un método

# Y mediante ese parámetro que cachamos, podemos llegar indirectamente al atributo que requerimos

# Lo que REALMENTE está pasando es:

# %% [markdown]
# <img src='data:image/jpg;base64,...'/>

# %% [markdown]
# <img src='data:image/jpg;base64,...'/>

# %%
# Ejemplo 7
class Persona():
    
    str_Nombre = ''
    str_Apellido = ''
    
    def Saludar(self):
        print('¡Hola!')
        
    def Presentarse(self):
        print('Mi nombre es: ', self.str_Nombre)

# %%
obj_Persona = Persona()
obj_Persona.str_Nombre = 'Diego'
obj_Persona.str_Apellido = 'Villa'

# %%
obj_Persona.Presentarse()

# %%
Persona.Presentarse(obj_Persona)

# %%
# Ejemplo 8 - Constructor
class Persona():
    
    str_Nombre = ''
    str_Apellido = ''
    
    def __init__(self):
        print('Método constructor de Persona')
    
    def Saludar(self):
        print('¡Hola!')
        
    def Presentarse(self):
        print('Mi nombre es: ', self.str_Nombre)

# %%
obj_Persona = Persona()

# %%
obj_Persona.Presentarse()

# %%
# Ejemplo 9 - Constructor
class Persona():
    
    str_Nombre = ''
    str_Apellido = ''
    
    def __init__(self, par_Nombre, par_Apellido):
        print('Método constructor de Persona')
        self.str_Nombre = par_Nombre
        self.str_Apellido = par_Apellido
    
    def Saludar(self):
        print('¡Hola!')
        
    def Presentarse(self):
        print('Mi nombre es: ', self.str_Nombre)

# %%
obj_Persona = Persona('Diego', 'Villa')

# %%
obj_Persona.Presentarse()

# %%
##############################                             ##############################
##############################   Any question so far...?   ##############################
##############################                             ##############################

# %%
##############################                             ##############################
##############################            AWESOME!         ##############################
##############################                             ##############################

# %%
################# Posibilidades de la programación orientada a objetos ################

# Hasta el momento hemos visto que podemos tener atributos sencillos como strings,
# sin embargo podemos tener todo tipo de datos como números, arreglos, booleanos y
# tal cual podemos tener OBJETOS como atributos.

# %%
# Ejemplo 10 - 
import datetime

class Celular():
    
    str_Marca = ''
    str_Modelo = ''
    nbr_Precio = 0
    
    def __init__(self, par_MarcaCel, par_ModeloCel, par_Precio):
        print('Método constructor de Celular')
        self.str_Marca = par_MarcaCel
        self.str_Modelo = par_ModeloCel
        self.nbr_Precio = par_Precio
    
    def MostrarInformacionGeneral(self):
        print('Soy un celular Marca: ', self.str_Marca)
        print('Soy un celular Modelo: ', self.str_Modelo)
    
    def DarLaHora(self):
        print('La hora es: ', datetime.datetime.now().time())

# %%
obj_Celular = Celular('Samsung', 'Galaxy', 2000)
obj_Celular.MostrarInformacionGeneral()
obj_Celular.DarLaHora()

# %%
# Ejemplo 11 - 
class Persona():
    
    str_Nombre = ''
    str_Apellido = ''
    obj_Celular = Celular('Samsung', 'Galaxy',2000)
    
    def __init__(self, par_Nombre, par_Apellido):
        print('Método constructor de Persona')
        self.str_Nombre = par_Nombre
        self.str_Apellido = par_Apellido
    
    def Saludar(self):
        print('¡Hola!')
        
    def Presentarse(self):
        self.Saludar()
        print('Mi nombre es: ', self.str_Nombre)

# %%
obj_Persona = Persona('Diego', 'Villa')

# %%
obj_Persona.obj_Celular.MostrarInformacionGeneral()
obj_Persona.obj_Celular.DarLaHora()

# %%
# Ejemplo 12 -         
class Persona():
    
    str_Nombre = ''
    str_Apellido = ''
    
    def __init__(self, par_Nombre, par_Apellido):
        print('Método constructor de Persona')
        self.str_Nombre = par_Nombre
        self.str_Apellido = par_Apellido
    
    def Saludar(self):
        print('¡Hola!')
        
    def Presentarse(self):
        self.Saludar()
        print('Mi nombre es: ', self.str_Nombre)

# %%
obj_Persona = Persona('Diego', 'Villa')

# %%
obj_Celular = Celular('Apple', 'iPhone', 2000)

# %%
### QUIZ: Ya deben saber: ¿Corre o no corre?
obj_Persona.obj_Celular = obj_Celular

# %%
obj_Persona.obj_Celular.MostrarInformacionGeneral()
obj_Persona.obj_Celular.DarLaHora()

# %%
# Ejemplo 13 - 
import datetime
        
class Persona():
    
    str_Nombre = ''
    str_Apellido = ''
    nbr_Dinero = 0
    
    def __init__(self, par_Nombre, par_Apellido):
        print('Método constructor de Persona')
        self.str_Nombre = par_Nombre
        self.str_Apellido = par_Apellido
    
    def Saludar(self):
        print('¡Hola!')
        
    def Presentarse(self):
        self.Saludar()
        print('Mi nombre es: ', self.str_Nombre)
        
    def ComprarCelular(self, par_Celular):
        
        if self.nbr_Dinero >= par_Celular.nbr_Precio:
            self.Celular = par_Celular
            print('Sí se compró el celular')
        else:
            print('No se compró el celular')

# %%
obj_Persona = Persona('Diego', 'Villa')
obj_Persona.nbr_Dinero = 1000

# %%
obj_Celular = Celular('Apple', 'iPhone', 2000)

# %%
obj_Persona.ComprarCelular(obj_Celular)

# %%
### QUIZ: De primara... ¿verdad?
obj_Persona.Celular.MostrarInformacionGeneral()
obj_Persona.Celular.DarLaHora()

# %%
obj_Persona.nbr_Dinero = 10000
obj_Persona.ComprarCelular(obj_Celular)

# %%
obj_Persona.Celular.MostrarInformacionGeneral()
obj_Persona.Celular.DarLaHora()

# %%
# Ejemplo 14
class Persona():
    
    str_Nombre = ''
    str_Apellido = ''
    nbr_Dinero = 0
    
    nbr_GrasaAcumulada = 0
    nbr_ProteinaAcumulada = 0
    nbr_AzucarAcumulada = 0
    nbr_FibraAcumulada = 0
    
    def __init__(self, par_Nombre, par_Apellido):
        print('Método constructor de Persona')
        self.str_Nombre = par_Nombre
        self.str_Apellido = par_Apellido
    
    def Saludar(self):
        print('¡Hola!')
        
    def Presentarse(self):
        self.Saludar()
        print('Mi nombre es: ', self.str_Nombre)

    def ComprarCelular(self, par_Celular):
        
        if self.nbr_Dinero >= par_Celular.nbr_Precio:
            self.Celular = par_Celular
            print('Sí se compró el celular')
        else:
            print('No se compró el celular')
    
    def DecirNivelesAlimentacion(self):
        print('Mi nivel de nbr_GrasaAcumulada es: ', self.nbr_GrasaAcumulada)
        print('Mi nivel de nbr_ProteinaAcumulada es: ', self.nbr_ProteinaAcumulada)
        print('Mi nivel de nbr_AzucarAcumulada es: ', self.nbr_AzucarAcumulada)
        print('Mi nivel de nbr_FibraAcumulada es: ', self.nbr_FibraAcumulada)

# %%
obj_Persona = Persona('Diego', 'Villa')
obj_Persona.Presentarse()
obj_Persona.DecirNivelesAlimentacion()

# %%
obj_Persona.nbr_GrasaAcumulada = 23
obj_Persona.nbr_ProteinaAcumulada = 43
obj_Persona.nbr_AzucarAcumulada = 56
obj_Persona.nbr_FibraAcumulada = 14

# %%
obj_Persona.DecirNivelesAlimentacion()

# %%
# Ejemplo 15
class Alimento():
    
    str_Nombre = ''
    
    nbr_Grasa = 0
    nbr_Proteina = 0
    nbr_Azucar = 0
    nbr_Fibra = 0
    
    def __init__(self, str_NombreDelAlimento):
        
        self.Nombre = str_NombreDelAlimento
        
        if str_NombreDelAlimento=='Tacos':
            self.nbr_Grasa = 20
            self.nbr_Proteina = 7
            self.nbr_Azucar = 8
            self.nbr_Fibra = 2
        elif str_NombreDelAlimento=='Pechuga con verduras':
            self.nbr_Grasa = 10
            self.nbr_Proteina = 15
            self.nbr_Azucar = 5
            self.nbr_Fibra = 5
        elif str_NombreDelAlimento=='Ensalada':
            self.nbr_Grasa = 1
            self.nbr_Proteina = 5
            self.nbr_Azucar = 1
            self.nbr_Fibra = 15

# %%
obj_Alimento1 = Alimento('Tacos')
obj_Alimento2 = Alimento('Pechuga con verduras')
obj_Alimento3 = Alimento('Ensalada')

# %%
print(obj_Alimento1.nbr_Grasa)
print(obj_Alimento2.nbr_Grasa)
print(obj_Alimento3.nbr_Grasa)

# %%
# Ejemplo 16            
class Persona():
    
    str_Nombre = ''
    str_Apellido = ''
    nbr_Dinero = 0
    
    nbr_GrasaAcumulada = 0
    nbr_ProteinaAcumulada = 0
    nbr_AzucarAcumulada = 0
    nbr_FibraAcumulada = 0
    
    def __init__(self, par_Nombre, par_Apellido):
        print('Método constructor de Persona')
        self.str_Nombre = par_Nombre
        self.str_Apellido = par_Apellido
    
    def Saludar(self):
        print('¡Hola!')
        
    def Presentarse(self):
        self.Saludar()
        print('Mi nombre es: ', self.str_Nombre)

    def ComprarCelular(self, par_Celular):
        
        if self.nbr_Dinero >= par_Celular.nbr_Precio:
            self.Celular = par_Celular
            print('Sí se compró el celular')
        else:
            print('No se compró el celular')
    
    def DecirNivelesAlimentacion(self):
        print('Mi nivel de nbr_GrasaAcumulada es: ', self.nbr_GrasaAcumulada)
        print('Mi nivel de nbr_ProteinaAcumulada es: ', self.nbr_ProteinaAcumulada)
        print('Mi nivel de nbr_AzucarAcumulada es: ', self.nbr_AzucarAcumulada)
        print('Mi nivel de nbr_FibraAcumulada es: ', self.nbr_FibraAcumulada)
        
    def Comer(self, par_Alimento):
        self.nbr_GrasaAcumulada += par_Alimento.nbr_Grasa
        self.nbr_ProteinaAcumulada += par_Alimento.nbr_Proteina
        self.nbr_AzucarAcumulada += par_Alimento.nbr_Azucar
        self.nbr_FibraAcumulada += par_Alimento.nbr_Fibra

# %%
obj_Persona = Persona('Diego', 'Villa')
obj_Persona.DecirNivelesAlimentacion()

# %%
obj_Alimento1 = Alimento('Tacos')
obj_Alimento2 = Alimento('Pechuga con verduras')
obj_Alimento3 = Alimento('Ensalada')

# %%
obj_Persona.Comer(obj_Alimento1)

# %%
obj_Persona.DecirNivelesAlimentacion()

# %%
##############################  -Do we need to study about inheritance?  ##############################
##############################  -Yes Marco, yes you need...              ##############################
##############################                                           ##############################
##############################               -Conversation with Nasser-  ##############################

# %%
############################## Herencia en programación orientada a objetos ##############################

# Así como en biología la herencia es la cualidad que tiene un organismo de tener las características
# de sus progenitores, el término de herencia en POO sería: la cualidad de que al crear
# un OBJETO, éste tenga incluidos los atributos y métodos de la clase padre.

# %%
class Estudiante():
    
    nbr_ClaveUnica = 0
    str_Carrera = ''
    
    def __init__(self):
        print('Método constructor de Estudiante')
    
    def DecirInfoAcad(self):
        print('Mis datos son: ', self.nbr_ClaveUnica, self.str_Carrera)

# %%
obj_Estudiante = Estudiante()
obj_Estudiante.nbr_ClaveUnica = 196756
obj_Estudiante.str_Carrera = 'Ciencia de Datos'

# %%
obj_Estudiante.DecirInfoAcad()

# %%
class Estudiante(Persona):
    
    nbr_ClaveUnica = 0
    str_Carrera = ''
    
    def __init__(self):
        print('Método constructor de Estudiante')
        super().__init__()
    
    def DecirInfoAcad(self):
        print('Mis datos son: ', self.nbr_ClaveUnica, self.str_Carrera)

# %%
obj_Estudiante = Estudiante()
obj_Estudiante.nbr_ClaveUnica = 196756
obj_Estudiante.str_Carrera = 'Ciencia de Datos'
obj_Estudiante.DecirInfoAcad()

# %%
class Estudiante(Persona):
    
    nbr_ClaveUnica = 0
    str_Carrera = ''
    
    def __init__(self):
        print('Método constructor de Estudiante')
        super().__init__('','')
    
    def DecirInfoAcad(self):
        print('Mis datos son: ', self.nbr_ClaveUnica, self.str_Carrera)

# %%
obj_Estudiante = Estudiante()
obj_Estudiante.nbr_ClaveUnica = 196756
obj_Estudiante.str_Carrera = 'Ciencia de Datos'
obj_Estudiante.DecirInfoAcad()

# %%
obj_Estudiante.Presentarse()

# %%
obj_Estudiante.str_Nombre = 'Diego'
obj_Estudiante.str_Apellido = 'Villa'
obj_Estudiante.Presentarse()

# %%
class Estudiante(Persona):
    
    nbr_ClaveUnica = 0
    str_Carrera = ''
    
    def __init__(self,  par_Nombre, par_Apellido):
        print('Método constructor de Estudiante')
        super().__init__(par_Nombre, par_Apellido)
    
    def DecirInfoAcad(self):
        print('Mis datos son: ', self.nbr_ClaveUnica, self.str_Carrera)

# %%
obj_Estudiante = Estudiante('Diego','Villa')
obj_Estudiante.nbr_ClaveUnica = 196756
obj_Estudiante.str_Carrera = 'Ciencia de Datos'
obj_Estudiante.DecirInfoAcad()

# %%
obj_Estudiante.Presentarse()

# %%
############################## Mini ejemplo del mundo real ##############################

# Crearemos un pipeline que realizará las siguientes acciones: 
# 1. Crear carpetas en S3 y esquemas y tablas en RDS
# 2. Bajar información de alguna página
# 3. Enviar archivos a S3
# 4. Enviar información a RDS
# 5. Visualizar un reporte

# %%
############################## ...habrá que hacer magia... ##############################
##############################                             ##############################
##############################                    -Adolfo- ##############################

# %%
# !pip3 install --user dynaconf
# !pip3 install --user boto3

# %%
import site
import sys

site.addsitedir('/usr/local/lib/python3.7/site-packages')
site.addsitedir('/Users/Marco/Library/Python/3.7/lib/python/site-packages')
sys.path

# %%
import requests

class UtileriaWeb():
    
    def DescargarRecurso(self, par_Url, par_NombreArchivoLocal):
        file = requests.get(par_Url)
        open(par_NombreArchivoLocal, 'wb').write(file.content)

# %%
import os
import boto3
from dynaconf import settings

# Código genérico respecto a S3
class UtileriaS3():

    # Atributos de conexión referentes a S3
    str_NombreBucket = ''
    
        # Constructor
    def __init__(self):
        
        # S3
        self.str_NombreBucket = settings.get('bucket_name')

    # Crea y devuelve una conexión a S3 para usarla como queramos
    def CrearConexionS3(self):

        from boto3 import Session
        session = Session()

        credentials = session.get_credentials()
        current_credentials = credentials.get_frozen_credentials()

        s3 = boto3.client(
                's3',
                aws_access_key_id=current_credentials.access_key,
                aws_secret_access_key=current_credentials.secret_key,
                aws_session_token=current_credentials.token,
                region_name='us-west-2',  # Oregon
                use_ssl=False
            )

        return s3

    def MandarArchivoS3(self, cnx_S3, bucket_name, str_RutaS3, str_Archivo):

        str_NombreArchivoEnS3 = str_RutaS3+os.path.basename(str_Archivo)
        cnx_S3.upload_file(str_Archivo, bucket_name, str_NombreArchivoEnS3)

        return

# %%
from dynaconf import settings

# Código genérico respecto a RDS
class UtileriaRDS():

    # Atributos de conexión referentes a RDS
    str_NombreDB = ''
    str_UsuarioDB = ''
    str_PassDB = ''
    str_EndPointDb = ''
    str_Port = ''

    # Constructor
    def __init__(self):
        
        # RDS
        self.str_NombreDB = settings.get('dbname')
        self.str_UsuarioDB = settings.get('user')
        self.str_PassDB = settings.get('password')
        self.str_EndPointDB = settings.get('host')
        self.str_Port = settings.get('port')
         
    # Crea y devuelve una conexión al RDS para poder usarla como queramos
    def CrearConexionRDS(self):

        import psycopg2
        import psycopg2.extras

        conn = psycopg2.connect(database=self.str_NombreDB,
                                user=self.str_UsuarioDB,
                                password=self.str_PassDB,
                                host=self.str_EndPointDB,
                                port=self.str_Port
                                )
        conn.autocommit = True
        
        return conn
    
    def InsertarEnRDSDesdeArchivo(self, conn, data_file, nombre_tabla):

        cur = conn.cursor()
        # Load table from the file with header
        cur.copy_expert("copy {} from STDIN CSV HEADER QUOTE '\"'".format(nombre_tabla), data_file)
        cur.execute("commit;")
        cur.close()

# %%
import os

# En esta clase pondremos código mega genérico que no esté ligado a algún problema en particular
class UtileriaGral():

    UtileriaWeb = UtileriaWeb()
    UtileriaS3 = UtileriaS3()
    UtileriaRDS = UtileriaRDS()
    
    def ObtenerTamanioArchivo(self, str_NombreArchivo):
        nbr_file_size = os.stat(str_NombreArchivo).st_size
        return nbr_file_size

# %%
# Tareas específicas de nuestro problema
class Trabajador(UtileriaGral):
    
    str_UrlWebScraping1 = ''
    str_NomArchDesc1 = ''
    str_NomArchDesc2 = ''
    str_NomArchDesc3 = ''
    
    str_NombreDirectorio = ''
    str_NombreDirectorio = ''
    str_NombreDirectorio = ''
    
    def __init__(self):
        super().__init__()
        
        self.str_UrlWebScraping1 = 'https://www.gutenberg.org/files/35/35-0.txt'
        self.str_NomArchDesc1 = 'archivo1_taller_POO.txt'
        
        self.str_UrlWebScraping2 = 'http://www.gutenberg.org/cache/epub/5200/pg5200.txt'
        self.str_NomArchDesc2 = 'archivo2_taller_POO.txt'
        
        self.str_UrlWebScraping3 = 'https://www.gutenberg.org/files/84/84-0.txt'
        self.str_NomArchDesc3 = 'archivo3_taller_POO.txt'
        
        self.str_NombreDirectorio1 = 'Directorio1/'
        self.str_NombreDirectorio2 = 'Directorio2/'
        self.str_NombreDirectorio3 = 'Directorio3/'
    
    def CrearInfraestructura(self):
        
        ############# Crear los directorios en S3 #############
        
        # Creamos conexión y directorio
        cnx_S3 = self.UtileriaS3.CrearConexionS3()
        cnx_S3.put_object(Bucket=self.UtileriaS3.str_NombreBucket, Key=(self.str_NombreDirectorio1))
        cnx_S3.put_object(Bucket=self.UtileriaS3.str_NombreBucket, Key=(self.str_NombreDirectorio2))
        cnx_S3.put_object(Bucket=self.UtileriaS3.str_NombreBucket, Key=(self.str_NombreDirectorio3))
        
        ############# Crear los esquemas y tablas en RDS #############

        str_Query1 = "drop schema if exists taller cascade;"
        str_Query2 = "create schema taller;"
        
        str_Query3 = "drop table if exists taller.tabla_ejemplo;" 
        str_Query4 = "create table taller.tabla_ejemplo ( " \
                     + " nombre_archivo VARCHAR(40), " \
                     + " tamanio_archivo VARCHAR(35) " \
                     + " );"

        cnx_RDS = self.UtileriaRDS.CrearConexionRDS()
        with cnx_RDS.cursor() as (cur):
            cur.execute(str_Query1)
            cur.execute(str_Query2)
            cur.execute(str_Query3)
            cur.execute(str_Query4)        
        
        return
    
    def HacerWebScraping(self):
        
        self.UtileriaWeb.DescargarRecurso(self.str_UrlWebScraping1, self.str_NomArchDesc1)
        self.UtileriaWeb.DescargarRecurso(self.str_UrlWebScraping2, self.str_NomArchDesc2)
        self.UtileriaWeb.DescargarRecurso(self.str_UrlWebScraping3, self.str_NomArchDesc3)
        
        return
    
    def EnviarInfoS3(self):
        
        cnx_S3 = self.UtileriaS3.CrearConexionS3()
        self.UtileriaS3.MandarArchivoS3(cnx_S3, self.UtileriaS3.str_NombreBucket, self.str_NombreDirectorio1, self.str_NomArchDesc1)
        self.UtileriaS3.MandarArchivoS3(cnx_S3, self.UtileriaS3.str_NombreBucket, self.str_NombreDirectorio2, self.str_NomArchDesc2)
        self.UtileriaS3.MandarArchivoS3(cnx_S3, self.UtileriaS3.str_NombreBucket, self.str_NombreDirectorio3, self.str_NomArchDesc3)
        
        return
    
    def ObtenerNombresArchivosDescargados(self):
    
        arr_Archivos = [self.str_NomArchDesc1, 
                        self.str_NomArchDesc2, 
                        self.str_NomArchDesc3]
        
        return arr_Archivos

# %%
class Auditor(UtileriaGral):
    
    str_ArchivoAuditoria = ''

    def __init__(self):
        super().__init__()
        self.str_ArchivoAuditoria = 'auditoria.csv'
        
    def AuditarDescargas(self, par_arrArchivos):
        
        import pandas as pd
        import numpy as np
        
        np_Campos = np.empty([0, 2])
        
        for elemento in par_arrArchivos:
            nbr_Tamanio=self.ObtenerTamanioArchivo(elemento)
            np_Campos = np.append(np_Campos, [[elemento,nbr_Tamanio]], axis=0)
            
        # Se pasa a un csv
        columns = ['id_archivo', 'tamanio']
        df = pd.DataFrame(data=np_Campos, columns=columns)
        df.to_csv(self.str_ArchivoAuditoria, index=False, header=True)    
            
        return
    
    def EnviarAuditoriaRDS(self):
        
        archivo = open(self.str_ArchivoAuditoria)
        cnx_RDS = self.UtileriaRDS.CrearConexionRDS()
        self.UtileriaRDS.InsertarEnRDSDesdeArchivo(cnx_RDS, archivo, 'taller.tabla_ejemplo')
        
        return
    
    def MostrarAuditoria(self):
        # Obtenemos la conexión
        cnx_RDS = self.UtileriaRDS.CrearConexionRDS()

        # Se abre el cursor
        with cnx_RDS.cursor() as (cur):
            # Ejecutamos el query
            cur.execute('select * from taller.tabla_ejemplo')
            
            # Obtenemos las filas y las barremos
            filas = cur.fetchall() 
            for fila in filas:
                print("Nombre archivo = ", fila[0])
                print("Tamaño archivo = ", fila[1])
        
        return

# %%
# En este 
class Orquestador():

    Trabajador = Trabajador()
    Auditor = Auditor()
    
    def CrearInfraestructura(self):
        print('-Ini: Controlador.CrearInfraestructura()')        
        self.Trabajador.CrearInfraestructura()
    
    def HacerWebScraping(self):
        print('-Ini: Controlador.HacerWebScraping()')
        self.Trabajador.HacerWebScraping()

    def EnviarInfoS3(self):
        print('-Ini: Controlador.EnviarInfoS3()')
        self.Trabajador.EnviarInfoS3()
    
    def ProcesoAuditoria(self):
        print('-Ini: Controlador.ProcesoAuditoria()')
        self.Auditor.AuditarDescargas(self.Trabajador.ObtenerNombresArchivosDescargados())
        self.Auditor.EnviarAuditoriaRDS()

    def MostrarResultados(self):
        print('-Ini: Controlador.MostrarResultados()')
        self.Auditor.MostrarAuditoria()

# %%
# Se crea el objeto Orquestador
obj_Orquestador = Orquestador()

# Se ejecuta el pipeline principal
obj_Orquestador.CrearInfraestructura()
obj_Orquestador.HacerWebScraping()
obj_Orquestador.EnviarInfoS3()
obj_Orquestador.ProcesoAuditoria()
obj_Orquestador.MostrarResultados()

# %%
obj_Control.Trabajador.str_UrlWebScraping1

# %%
obj_Control.Trabajador.UtileriaS3.str_NombreBucket

# %% [markdown]
# <img src='data:image/jpg;base64,...'/>
